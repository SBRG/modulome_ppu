# %% [markdown]
# # Searching for motifs

# %% [markdown]
# ## Using MEME to find motifs

# %% [markdown]
# [MEME](https://meme-suite.org/meme/) must be installed to use this functionality. `find_motifs` searches for motifs upstream of all genes in an iModulon. The `gene_table` must contain the columns `accession` and `operon` for this function to work (see `notebooks/gene_annotation.ipynb`).
#
# `find_motifs` supports many of the command-line options for MEME:
#
# * `outdir`: Directory for output files
# * `palindrome`: If True, limit search to palindromic motifs (default: False)
# * `nmotifs`: Number of motifs to search for (default: 5)
# * `upstream`: Number of basepairs upstream from first gene in operon to include in motif search (default: 500)
# * `downstream`: Number of basepairs upstream from first gene in operon to include in motif search (default: 100)
# * `verbose`: Show steps in verbose output (default: True)
# * `force`: Force execution of MEME even if output already exists (default: False)
# * `evt`: E-value threshold (default: 0.001)
# * `cores` Number of cores to use (default: 8)
# * `minw`: Minimum motif width in basepairs (default: 6)
# * `maxw`: Maximum motif width in basepairs (default: 40)
# * `minsites`: Minimum number of sites required for a motif. Default is the number of operons divided by 3.

# %%
from pymodulon.motif import *
from pymodulon.io import load_json_model

# %%
ica_data = load_json_model('../putidaPRECISE321.json')

# %%
pputida_fasta = "../data/sequence_files/genome.fasta"

# %%
for i in ica_data.imodulon_table.index:
    motifs = find_motifs(ica_data, i, pputida_fasta, outdir='./motif_search/tmp_maxw_30', maxw=30)
# Out:
# Less than two sequences found for iModulon: Null-1
# Finding motifs for 24 sequences
# Found 8 motifs across 119 sites
# Finding motifs for 3 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 48 sequences
# Found 4 motifs across 178 sites
# Finding motifs for 2 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 7 sequences
# No motif found with E-value < 1.0e-03
# Less than two sequences found for iModulon: Noise-1
# Finding motifs for 8 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 15 sequences
# Found 7 motifs across 46 sites
# Finding motifs for 50 sequences
# Found 2 motifs across 83 sites
# Finding motifs for 3 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 8 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 10 sequences
# Found 3 motifs across 18 sites
# Finding motifs for 10 sequences
# Found 2 motifs across 15 sites
# Finding motifs for 43 sequences
# Found 2 motifs across 82 sites
# Finding motifs for 13 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 9 sequences
# Found 2 motifs across 13 sites
# Finding motifs for 6 sequences
# Found 3 motifs across 14 sites
# Finding motifs for 5 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 19 sequences
# Found 6 motifs across 66 sites
# Finding motifs for 27 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 2 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 3 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 23 sequences
# Found 6 motifs across 77 sites
# Finding motifs for 8 sequences
# Found 1 motif across 7 sites
# Finding motifs for 5 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 8 sequences
# Found 1 motif across 6 sites
# Finding motifs for 4 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 6 sequences
# No motif found with E-value < 1.0e-03
# Less than two sequences found for iModulon: Noise-2
# Finding motifs for 19 sequences
# Found 7 motifs across 70 sites
# Finding motifs for 9 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 4 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 2 sequences
# No motif found with E-value < 1.0e-03
# Less than two sequences found for iModulon: Null-2
# Finding motifs for 3 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 4 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 27 sequences
# Found 2 motifs across 47 sites
# Finding motifs for 25 sequences
# Found 3 motifs across 69 sites
# Finding motifs for 9 sequences
# Found 9 motifs across 51 sites
# Finding motifs for 4 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 12 sequences
# Found 1 motif across 8 sites
# Finding motifs for 56 sequences
# No motif found with E-value < 1.0e-03
# Less than two sequences found for iModulon: AcoR
# Finding motifs for 6 sequences
# Found 1 motif across 4 sites
# Finding motifs for 3 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 5 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 67 sequences
# Found 2 motifs across 64 sites
# Finding motifs for 4 sequences
# No motif found with E-value < 1.0e-03
# Less than two sequences found for iModulon: AmrZ
# Less than two sequences found for iModulon: Noise-3
# Finding motifs for 20 sequences
# Found 7 motifs across 58 sites
# Finding motifs for 4 sequences
# Found 9 motifs across 36 sites
# Finding motifs for 3 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 4 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 16 sequences
# Found 1 motif across 14 sites
# Finding motifs for 3 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 17 sequences
# Found 7 motifs across 61 sites
# Finding motifs for 17 sequences
# Found 4 motifs across 50 sites
# Finding motifs for 9 sequences
# Found 4 motifs across 26 sites
# Finding motifs for 4 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 11 sequences
# Found 2 motifs across 17 sites
# Finding motifs for 12 sequences
# No motif found with E-value < 1.0e-03
# Less than two sequences found for iModulon: Noise-4
# Finding motifs for 9 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 32 sequences
# Found 4 motifs across 71 sites
# Finding motifs for 2 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 9 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 18 sequences
# Found 4 motifs across 54 sites
# Finding motifs for 12 sequences
# Found 1 motif across 12 sites
# Finding motifs for 2 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 27 sequences
# Found 5 motifs across 94 sites
# Less than two sequences found for iModulon: PP_2260-3
# Finding motifs for 2 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 4 sequences
# No motif found with E-value < 1.0e-03
# Less than two sequences found for iModulon: Noise-5
# Finding motifs for 8 sequences
# Found 4 motifs across 25 sites
# Finding motifs for 2 sequences
# No motif found with E-value < 1.0e-03
# Finding motifs for 2 sequences
# No motif found with E-value < 1.0e-03
# Less than two sequences found for iModulon: Null-3
# Less than two sequences found for iModulon: GlcC
# Finding motifs for 5 sequences
# No motif found with E-value < 1.0e-03
# Less than two sequences found for iModulon: Genomic-3
# Less than two sequences found for iModulon: Noise-6

# %% [markdown]
# This `MotifInfo` object is automatically stored as a dictionary in the IcaData object. It will persist after saving and re-loading the IcaData object.

# %%
ica_data.motif_info
# Out:
# {'GbdR': <MotifInfo with 8 motifs across 119 sites>,
#  'Multiple stress-1': <MotifInfo with 4 motifs across 178 sites>,
#  'Zinc': <MotifInfo with 7 motifs across 46 sites>,
#  'TCA cycle': <MotifInfo with 2 motifs across 83 sites>,
#  'GclR': <MotifInfo with 3 motifs across 18 sites>,
#  'FnrA-1': <MotifInfo with 2 motifs across 15 sites>,
#  'Osmotic stress-1': <MotifInfo with 2 motifs across 82 sites>,
#  'Multiple stress-2': <MotifInfo with 2 motifs across 13 sites>,
#  'Putrescine': <MotifInfo with 3 motifs across 14 sites>,
#  'Zur': <MotifInfo with 6 motifs across 66 sites>,
#  'Osmotic stress-2': <MotifInfo with 6 motifs across 77 sites>,
#  'ColR': <MotifInfo with 1 motif across 7 sites>,
#  'Exporters': <MotifInfo with 1 motif across 6 sites>,
#  'PvdS': <MotifInfo with 7 motifs across 70 sites>,
#  'PydR/RpoS': <MotifInfo with 2 motifs across 47 sites>,
#  'FliA': <MotifInfo with 3 motifs across 69 sites>,
#  'PplR1': <MotifInfo with 9 motifs across 51 sites>,
#  'Unchar-5': <MotifInfo with 1 motif across 8 sites>,
#  'TurA-1': <MotifInfo with 1 motif across 4 sites>,
#  'Unchar-7': <MotifInfo with 2 motifs across 64 sites>,
#  'Phage-2': <MotifInfo with 7 motifs across 58 sites>,
#  'HexR': <MotifInfo with 9 motifs across 36 sites>,
#  'Translation': <MotifInfo with 1 motif across 14 sites>,
#  'PedR1-2': <MotifInfo with 7 motifs across 61 sites>,
#  'PP_0204/CysB': <MotifInfo with 4 motifs across 50 sites>,
#  'IonicLiquid': <MotifInfo with 4 motifs across 26 sites>,
#  'Unchar-8': <MotifInfo with 2 motifs across 17 sites>,
#  'PcaR': <MotifInfo with 4 motifs across 71 sites>,
#  'FleQ/AmrZ': <MotifInfo with 4 motifs across 54 sites>,
#  'FnrA-2': <MotifInfo with 1 motif across 12 sites>,
#  'FleQ/Fur': <MotifInfo with 5 motifs across 94 sites>,
#  'LiuR': <MotifInfo with 4 motifs across 25 sites>}

# %% [markdown]
# ## Using TOMTOM to compare motifs against external databases

# %% [markdown]
# Once you have a motif from MEME, you can use [TOMTOM](https://meme-suite.org/meme/tools/tomtom) to compare your motif against external databases. The `compare_motifs` function makes this process simple.
#
# The `MotifInfo` object generated in the `find_motifs` function contains the MEME file location, which is the primary input for `compare_motifs`.

# %%
for i in ica_data.motif_info:
    compare_motifs(ica_data.motif_info[i], verbose=False)
# Out:
# Writing results to output directory './motif_search/tmp_maxw_30/GbdR/tomtom'.
# Processing query 1 out of 8
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.944943
# #   Estimated pi_0=0.944943
# Processing query 2 out of 8
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00063
# #   Estimated pi_0=1
# Processing query 3 out of 8
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.966627
# #   Estimated pi_0=0.967779
# Processing query 4 out of 8
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.907713
# #   Estimated pi_0=0.910023
# Processing query 5 out of 8
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.959457
# #   Estimated pi_0=0.960094
# Processing query 6 out of 8
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.961892
# #   Estimated pi_0=0.962748
# Processing query 7 out of 8
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.971201
# #   Estimated pi_0=0.971201
# Processing query 8 out of 8
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.951079
# #   Estimated pi_0=0.954604
# Writing results to output directory './motif_search/tmp_maxw_30/Multiple_stress-1/tomtom'.
# Processing query 1 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.964114
# #   Estimated pi_0=0.968227
# Processing query 2 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.934613
# #   Estimated pi_0=0.937134
# Processing query 3 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.923649
# #   Estimated pi_0=0.924583
# Processing query 4 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.948437
# #   Estimated pi_0=0.952431
# Writing results to output directory './motif_search/tmp_maxw_30/Zinc/tomtom'.
# Processing query 1 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.994509
# #   Estimated pi_0=0.994509
# Processing query 2 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.990161
# #   Estimated pi_0=0.992074
# Processing query 3 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00162
# #   Estimated pi_0=1
# Processing query 4 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.999073
# #   Estimated pi_0=0.999073
# Processing query 5 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.999073
# #   Estimated pi_0=0.999073
# Processing query 6 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00332
# #   Estimated pi_0=1
# Processing query 7 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00395
# #   Estimated pi_0=1
# Writing results to output directory './motif_search/tmp_maxw_30/TCA_cycle/tomtom'.
# Processing query 1 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.925283
# #   Estimated pi_0=0.927137
# Processing query 2 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.937676
# #   Estimated pi_0=0.940122
# Writing results to output directory './motif_search/tmp_maxw_30/GclR/tomtom'.
# Processing query 1 out of 3
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00247
# #   Estimated pi_0=1
# Processing query 2 out of 3
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.964996
# #   Estimated pi_0=0.966133
# Processing query 3 out of 3
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.988371
# #   Estimated pi_0=0.989402
# Writing results to output directory './motif_search/tmp_maxw_30/FnrA-1/tomtom'.
# Processing query 1 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.964467
# #   Estimated pi_0=0.966758
# Processing query 2 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.991557
# #   Estimated pi_0=0.9918
# Writing results to output directory './motif_search/tmp_maxw_30/Osmotic_stress-1/tomtom'.
# Processing query 1 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.926681
# #   Estimated pi_0=0.927137
# Processing query 2 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.93237
# #   Estimated pi_0=0.935398
# Writing results to output directory './motif_search/tmp_maxw_30/Multiple_stress-2/tomtom'.
# Processing query 1 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.98972
# #   Estimated pi_0=0.98972
# Processing query 2 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.985726
# #   Estimated pi_0=0.98887
# Writing results to output directory './motif_search/tmp_maxw_30/Putrescine/tomtom'.
# Processing query 1 out of 3
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.990666
# #   Estimated pi_0=0.996428
# Processing query 2 out of 3
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00247
# #   Estimated pi_0=1
# Processing query 3 out of 3
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00332
# #   Estimated pi_0=1
# Writing results to output directory './motif_search/tmp_maxw_30/Zur/tomtom'.
# Processing query 1 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.958527
# #   Estimated pi_0=0.960014
# Processing query 2 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.930626
# #   Estimated pi_0=0.931498
# Processing query 3 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.966884
# #   Estimated pi_0=0.966884
# Processing query 4 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.990193
# #   Estimated pi_0=0.99301
# Processing query 5 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00149
# #   Estimated pi_0=1
# Processing query 6 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.985685
# #   Estimated pi_0=0.98688
# Writing results to output directory './motif_search/tmp_maxw_30/Osmotic_stress-2/tomtom'.
# Processing query 1 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.999846
# #   Estimated pi_0=1
# Processing query 2 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.999073
# #   Estimated pi_0=0.999073
# Processing query 3 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00077
# #   Estimated pi_0=1
# Processing query 4 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.946764
# #   Estimated pi_0=0.948098
# Processing query 5 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.947547
# #   Estimated pi_0=0.950686
# Processing query 6 out of 6
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.970747
# #   Estimated pi_0=0.974001
# Writing results to output directory './motif_search/tmp_maxw_30/ColR/tomtom'.
# Processing query 1 out of 1
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.997511
# #   Estimated pi_0=1
# Writing results to output directory './motif_search/tmp_maxw_30/Exporters/tomtom'.
# Processing query 1 out of 1
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00326
# #   Estimated pi_0=1
# Writing results to output directory './motif_search/tmp_maxw_30/PvdS/tomtom'.
# Processing query 1 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.949475
# #   Estimated pi_0=0.949475
# Processing query 2 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.994403
# #   Estimated pi_0=0.996522
# Processing query 3 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00417
# #   Estimated pi_0=1
# Processing query 4 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.971424
# #   Estimated pi_0=0.971424
# Processing query 5 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00077
# #   Estimated pi_0=1
# Processing query 6 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00503
# #   Estimated pi_0=1
# Processing query 7 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00077
# #   Estimated pi_0=1
# Writing results to output directory './motif_search/tmp_maxw_30/PydR_RpoS/tomtom'.
# Processing query 1 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.914959
# #   Estimated pi_0=0.915487
# Processing query 2 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.923912
# #   Estimated pi_0=0.926681
# Writing results to output directory './motif_search/tmp_maxw_30/FliA/tomtom'.
# Processing query 1 out of 3
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.942837
# #   Estimated pi_0=0.942837
# Processing query 2 out of 3
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.995168
# #   Estimated pi_0=0.997373
# Processing query 3 out of 3
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.915029
# #   Estimated pi_0=0.919939
# Writing results to output directory './motif_search/tmp_maxw_30/PplR1/tomtom'.
# Processing query 1 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.998909
# #   Estimated pi_0=1
# Processing query 2 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00247
# #   Estimated pi_0=1
# Processing query 3 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00247
# #   Estimated pi_0=1
# Processing query 4 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.0004
# #   Estimated pi_0=1
# Processing query 5 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00247
# #   Estimated pi_0=1
# Processing query 6 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00332
# #   Estimated pi_0=1
# Processing query 7 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.997923
# #   Estimated pi_0=1
# Processing query 8 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00162
# #   Estimated pi_0=1
# Processing query 9 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.953539
# #   Estimated pi_0=0.953859
# Writing results to output directory './motif_search/tmp_maxw_30/Unchar-5/tomtom'.
# Processing query 1 out of 1
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.973151
# #   Estimated pi_0=0.974236
# Writing results to output directory './motif_search/tmp_maxw_30/TurA-1/tomtom'.
# Processing query 1 out of 1
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00332
# #   Estimated pi_0=1
# Writing results to output directory './motif_search/tmp_maxw_30/Unchar-7/tomtom'.
# Processing query 1 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.946325
# #   Estimated pi_0=0.95081
# Processing query 2 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.939131
# #   Estimated pi_0=0.940814
# Writing results to output directory './motif_search/tmp_maxw_30/Phage-2/tomtom'.
# Processing query 1 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00247
# #   Estimated pi_0=1
# Processing query 2 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00417
# #   Estimated pi_0=1
# Processing query 3 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.0032
# #   Estimated pi_0=1
# Processing query 4 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00247
# #   Estimated pi_0=1
# Processing query 5 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.999073
# #   Estimated pi_0=0.999073
# Processing query 6 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.998137
# #   Estimated pi_0=1
# Processing query 7 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00247
# #   Estimated pi_0=1
# Writing results to output directory './motif_search/tmp_maxw_30/HexR/tomtom'.
# Processing query 1 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00077
# #   Estimated pi_0=1
# Processing query 2 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00332
# #   Estimated pi_0=1
# Processing query 3 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00162
# #   Estimated pi_0=1
# Processing query 4 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00503
# #   Estimated pi_0=1
# Processing query 5 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.98972
# #   Estimated pi_0=0.98972
# Processing query 6 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00241
# #   Estimated pi_0=1
# Processing query 7 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.997373
# #   Estimated pi_0=0.997373
# Processing query 8 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00332
# #   Estimated pi_0=1
# Processing query 9 out of 9
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00247
# #   Estimated pi_0=1
# Writing results to output directory './motif_search/tmp_maxw_30/Translation/tomtom'.
# Processing query 1 out of 1
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.999846
# #   Estimated pi_0=0.999923
# Writing results to output directory './motif_search/tmp_maxw_30/PedR1-2/tomtom'.
# Processing query 1 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00156
# #   Estimated pi_0=1
# Processing query 2 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.999923
# #   Estimated pi_0=0.999923
# Processing query 3 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.975777
# #   Estimated pi_0=0.97897
# Processing query 4 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.966627
# #   Estimated pi_0=0.969402
# Processing query 5 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00063
# #   Estimated pi_0=1
# Processing query 6 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00503
# #   Estimated pi_0=1
# Processing query 7 out of 7
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.98658
# #   Estimated pi_0=0.992038
# Writing results to output directory './motif_search/tmp_maxw_30/PP_0204_CysB/tomtom'.
# Processing query 1 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.966021
# #   Estimated pi_0=0.966021
# Processing query 2 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.980859
# #   Estimated pi_0=0.98259
# Processing query 3 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00417
# #   Estimated pi_0=1
# Processing query 4 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.997373
# #   Estimated pi_0=0.997373
# Writing results to output directory './motif_search/tmp_maxw_30/IonicLiquid/tomtom'.
# Processing query 1 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.998137
# #   Estimated pi_0=0.999073
# Processing query 2 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00077
# #   Estimated pi_0=1
# Processing query 3 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00247
# #   Estimated pi_0=1
# Processing query 4 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.98174
# #   Estimated pi_0=0.98383
# Writing results to output directory './motif_search/tmp_maxw_30/Unchar-8/tomtom'.
# Processing query 1 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.965989
# #   Estimated pi_0=0.968763
# Processing query 2 out of 2
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.0032
# #   Estimated pi_0=1
# Writing results to output directory './motif_search/tmp_maxw_30/PcaR/tomtom'.
# Processing query 1 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.992783
# #   Estimated pi_0=0.993864
# Processing query 2 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.948084
# #   Estimated pi_0=0.953072
# Processing query 3 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.935448
# #   Estimated pi_0=0.937604
# Processing query 4 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.970465
# #   Estimated pi_0=0.972491
# Writing results to output directory './motif_search/tmp_maxw_30/FleQ_AmrZ/tomtom'.
# Processing query 1 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.949673
# #   Estimated pi_0=0.951559
# Processing query 2 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.993646
# #   Estimated pi_0=0.995672
# Processing query 3 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.96739
# #   Estimated pi_0=0.96739
# Processing query 4 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.999768
# #   Estimated pi_0=0.999923
# Writing results to output directory './motif_search/tmp_maxw_30/FnrA-2/tomtom'.
# Processing query 1 out of 1
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.974001
# #   Estimated pi_0=0.974209
# Writing results to output directory './motif_search/tmp_maxw_30/FleQ_Fur/tomtom'.
# Processing query 1 out of 5
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.915696
# #   Estimated pi_0=0.915696
# Processing query 2 out of 5
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.959124
# #   Estimated pi_0=0.961704
# Processing query 3 out of 5
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.983503
# #   Estimated pi_0=0.983609
# Processing query 4 out of 5
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.945243
# #   Estimated pi_0=0.949093
# Processing query 5 out of 5
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.987174
# #   Estimated pi_0=0.988466
# Writing results to output directory './motif_search/tmp_maxw_30/LiuR/tomtom'.
# Processing query 1 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00332
# #   Estimated pi_0=1
# Processing query 2 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.971591
# #   Estimated pi_0=0.97227
# Processing query 3 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 1.00247
# #   Estimated pi_0=1
# Processing query 4 out of 4
# # Computing q-values.
# #   Estimating pi_0 from all 1182 observed p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.994719
# #   Estimated pi_0=0.995672

# %% [markdown]
# # Generating a table summarizing results of motif search

# %%
motif_table=pd.DataFrame(index=list)

for i in motif_table.index:
    a = ica_data.motif_info[i].sites
    
    if i != 'PvdS':
        motif_table.loc[i,'Oplists'] = a.loc['MEME-1'][-a.loc['MEME-1','pvalue'].isna()].index
    else:
        motif_table.loc[i,'Oplists'] = a.loc['MEME-4'][-a.loc['MEME-4','pvalue'].isna()].index

# %%
for i in motif_table.index:
    motif_table.loc[i,'Op_num']=len(motif_table.loc[i,'Oplists'])
   
    motif_table.loc[i,'Op_total_num']=len(ica_data.view_imodulon(i).operon.unique())


    gene_num=0
    
    for j in motif_table.loc[i,'Oplists']:
        gene_num = gene_num+len(ica_data.view_imodulon(i).operon[ica_data.view_imodulon(i).operon == j])
        
    motif_table.loc[i,'motif_gene_num'] = gene_num
    
    motif_table.loc[i,'gene_total_num']=len(ica_data.view_imodulon(i))
    
    if i != 'PvdS':
        motif_table.loc[i,'consensus'] = ica_data.motif_info[i].motifs.loc['MEME-1','consensus']
        motif_table.loc[i,'width'] = ica_data.motif_info[i].motifs.loc['MEME-1','width']

    else:
        motif_table.loc[i,'consensus'] = ica_data.motif_info[i].motifs.loc['MEME-4','consensus']
        motif_table.loc[i,'width'] = ica_data.motif_info[i].motifs.loc['MEME-4','width']

# %%
motif_table.drop(columns=['Oplists']).to_csv('./motif_search/motif_table.csv')

# %%
from pymodulon.io import *
save_to_json(ica_data,'../putidaPRECISE321.json')
